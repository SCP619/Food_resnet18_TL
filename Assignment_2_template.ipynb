# %% [markdown]
# ### Assignment 2 Understanding transfer learning and fine tuning

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data import Dataset
import torch.nn.functional as F
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from torch.utils.data import random_split
from torchvision import datasets
import os 
import numpy as np 
from typing import Literal
from torchvision.models import resnet18, ResNet18_Weights
from sklearn.metrics import accuracy_score



print(f"[INFO] Torch infos: {torch.__version__}")
# Out:
# [INFO] Torch infos: 2.9.1+cu128

# %% [markdown]
# # We need transform from resnet18 and its weights

# %%
transform = ResNet18_Weights.DEFAULT.transforms()

# %% [markdown]
# # pick a dataset  you can import from
#
# ```python
# from torchvision import datasets
# ```
#
# # Easy picks:
#
# - Food101
# - Flowers102
# - DTD
# - FGVAircraft
#
# # Other picks:
#
# ```python
#
# full_train = datasets.OxfordIIITPet(root="data", split="trainval", download=True, transform=transform)
# test_ds    = datasets.OxfordIIITPet(root="data", split="test", download=True, transform=transform)
#
# ```

# %% [markdown]
# # Split the data

# %%
data = datasets.Food101(root="Dataset",split="train", transform=transform)

test_ds = datasets.Food101(root="Dataset",split="test", transform=transform)

# %% [markdown]
# # load the train, validation and test split

# %%
print(data)
print(test_ds)
images= len(data)
# print(images)
val_ratio = 0.2
train_images = int(images *(1-val_ratio))
val_images = int(images*val_ratio)
print (f'toatl images {images}, val images {val_images}, train images {train_images}')
# Out:
# Dataset Food101
#     Number of datapoints: 75750
#     Root location: Dataset
#     split=train
#     StandardTransform
# Transform: ImageClassification(
#                crop_size=[224]
#                resize_size=[256]
#                mean=[0.485, 0.456, 0.406]
#                std=[0.229, 0.224, 0.225]
#                interpolation=InterpolationMode.BILINEAR
#            )
# Dataset Food101
#     Number of datapoints: 25250
#     Root location: Dataset
#     split=test
#     StandardTransform
# Transform: ImageClassification(
#                crop_size=[224]
#                resize_size=[256]
#                mean=[0.485, 0.456, 0.406]
#                std=[0.229, 0.224, 0.225]
#                interpolation=InterpolationMode.BILINEAR
#            )
# toatl images 75750, val images 15150, train images 60600

# %%
train_split, val_split = random_split(data, [train_images,val_images])

# %% [markdown]
# # create dataloader handler from the dataset

# %%
train_loader = DataLoader(train_split,batch_size=128,shuffle = True, num_workers=2,pin_memory=True)
val_loader = DataLoader(val_split,batch_size=128,shuffle = False, num_workers=2,pin_memory=True)
test_loader =  DataLoader(test_ds,batch_size=128,num_workers=2,pin_memory=True)

# %% [markdown]
# # now create the cnn, use the resnet18 as backbone, and ResNet18_Weights as initial weights.
# - create the backbone
# - create a classifier
# - based on your dataset add the correct number of output classes
# - the classifier have to be trainable.
#
# # Question 1?
# - Why we freeze the backbone? Why not the classifier?

# %% [markdown]
# Because I am not training the model. I am using the already trained model so the model already knows how to recognise edges, textures and shapes. If i didnt freeze the backbone, that would trigger back propagation to re adjust the weights. I am freezingthe backbone so the classifier can first learn how to interpret existing features specifically for Food101 labels.

# %% [markdown]
# # add the train evaluation, and predict functions here

# %%
model = resnet18(weights=ResNet18_Weights.DEFAULT)
print(model.fc)
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %%
model.fc = nn.Linear(512, 101)

optimizer = optim.Adam

# %% [markdown]
# ### Phase 1: Transfer learning

# %% [markdown]
# # freeze all layers except the classifier.
# - train and evaluate the model for 50 epochs
# - remember to save val loss and train loss

# %%
model.fc = nn.Linear(512, 101)
for p in model.parameters():
    p.requires_grad = False
    
# for p in model.classifier.parameters():
#     p.requires_grad = True

for p in model.fc.parameters():
    p.requires_grad = True

# %% [markdown]
# # Plot accuracy and loss

# %% [markdown]
# # plot predictions

# %% [markdown]
# # calculate TEST accuracy score

# %% [markdown]
# # Calculate confusion matrices precision and recall

# %% [markdown]
# ### Phase 2: Freeze layer 4 - Fine tuning

# %% [markdown]
# # from the freezed cnn unfreeze the  ``` layer4 ```.

# %% [markdown]
# # Train for 50 epochs

# %% [markdown]
# # Plot curves

# %% [markdown]
# # visualize prediction

# %% [markdown]
# # Calculate test accuracy score

# %% [markdown]
# # calculate confusion matrix precision and recall

# %% [markdown]
# # Question 2 What did you learn? What is the difference between transfer learning and fine tuning?
